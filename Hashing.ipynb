# %% [markdown]
# <a href="https://colab.research.google.com/github/putri-senja/Struktur-Data/blob/main/Hashing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Implementasi Hash Table Sederhana

class SimpleHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        self.table[index] = value

    def search(self, key):
        index = self.hash_function(key)
        return self.table[index]

# Contoh penggunaan
ht = SimpleHashTable(10)
ht.insert("apel", 100)
ht.insert("pisang", 200)

print("Nilai untuk 'apel':", ht.search("apel"))
print("Nilai untuk 'pisang':", ht.search("pisang"))
# Out:
# Nilai untuk 'apel': 100
# Nilai untuk 'pisang': 200

# %%
# Penanganan Collision dengan Linear Probing

class LinearProbingHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        original_index = index

        while self.table[index] is not None:
            if self.table[index][0] == key:
                break
            index = (index + 1) % self.size
            if index == original_index:
                raise Exception("Hash table penuh")

        self.table[index] = (key, value)

    def search(self, key):
        index = self.hash_function(key)
        original_index = index

        while self.table[index] is not None:
            if self.table[index][0] == key:
                return self.table[index][1]
            index = (index + 1) % self.size
            if index == original_index:
                break

        return None

# Contoh penggunaan
ht = LinearProbingHashTable(5)
ht.insert("apel", 100)
ht.insert("pisang", 200)
ht.insert("melon", 300)

print("Nilai untuk 'apel':", ht.search("apel"))
print("Nilai untuk 'melon':", ht.search("melon"))
# Out:
# Nilai untuk 'apel': 100
# Nilai untuk 'melon': 300

# %%
# Penanganan Collision dengan Chaining

class ChainingHashTable:
    def __init__(self, size):
        self.table = [[] for _ in range(size)]
        self.size = size

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        for i, (k, v) in enumerate(self.table[index]):
            if k == key:
                self.table[index][i] = (key, value)
                return
        self.table[index].append((key, value))

    def search(self, key):
        index = self.hash_function(key)
        for k, v in self.table[index]:
            if k == key:
                return v
        return None

# Contoh penggunaan
ht = ChainingHashTable(5)
ht.insert("apel", 100)
ht.insert("pisang", 200)
ht.insert("melon", 300)

print("Nilai untuk 'apel':", ht.search("apel"))
print("Nilai untuk 'melon':", ht.search("melon"))
# Out:
# Nilai untuk 'apel': 100
# Nilai untuk 'melon': 300

# %%
# Latihan / Tugas
# Eksperimen Sederhana Linear Probing

# Menggunakan kelas LinearProbingHashTable dari materi sebelumnya
ht_lp = LinearProbingHashTable(5)

# a & b. Memasukkan 5 data ke dalam tabel berukuran 5
ht_lp.insert("A", 10)
ht_lp.insert("B", 20)
ht_lp.insert("C", 30)
ht_lp.insert("D", 40)
ht_lp.insert("E", 50)

# c. Cetak isi array self.table setelah semua data dimasukkan
print("Isi tabel Linear Probing:", ht_lp.table)
# Out:
# Isi tabel Linear Probing: [('D', 40), ('B', 20), ('E', 50), ('A', 10), ('C', 30)]

# %%
# Latihan / Tugas
# Percobaan Dasar Chaining

# Menggunakan kelas ChainingHashTable dari materi sebelumnya
ht_chain = ChainingHashTable(3)

# a & b. Memasukkan data ke tabel berukuran 3
ht_chain.insert("apel", 100)
ht_chain.insert("melon", 200)
ht_chain.insert("lemon", 300)
ht_chain.insert("pisang", 400)

# c. Cetak isi tabel dan tampilkan semua data di setiap slot
print("Isi tabel Chaining:")
for indeks, slot in enumerate(ht_chain.table):
    print(f"Slot {indeks}: {slot}")
# Out:
# Isi tabel Chaining:
# Slot 0: [('lemon', 300)]
# Slot 1: [('melon', 200)]
# Slot 2: [('apel', 100), ('pisang', 400)]
