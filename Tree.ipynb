# %% [markdown]
# <a href="https://colab.research.google.com/github/putri-senja/Struktur-Data/blob/main/Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Binary Tree Secara Manual

class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None

# Membuat tree secara manual
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

# Fungsi inorder traversal
def inorder(node):
  if node:
    inorder(node.left)
    print(node.data, end=' ')
    inorder(node.right)

# Memanggil fungsi inorder traversal
print("Hasil inorder traversal dari binary tree:")
inorder(root)
# Out:
# Hasil inorder traversal dari binary tree:
# 4 2 5 1 3

# %%
# Membuat Binary Search Tree

class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None

class BinarySearchTree:
  def __init__(self):
    self.root = None
  def insert(self, root, data):
    if root is None:
      return Node(data)
    if data < root.data:
      root.left = self.insert(root.left, data)
    else:
      root.right = self.insert(root.right, data)
    return root

bst = BinarySearchTree()
root = None
data_list = [50, 30, 70, 20, 40, 60, 80]
for value in data_list:
  root = bst.insert(root, value)

# %%
# Traversal pada BST

def inorder(node):
  if node:
    inorder(node.left)
    print(node.data, end=' ')
    inorder(node.right)

def preorder(node):
  if node:
    print(node.data, end=' ')
    preorder(node.left)
    preorder(node.right)

def postorder(node):
  if node:
    postorder(node.left)
    postorder(node.right)
    print(node.data, end=' ')

print("Inorder traversal:")
inorder(root)
print("\nPreorder traversal:")
preorder(root)
print("\nPostorder traversal:")
postorder(root)
# Out:
# Inorder traversal:
# 20 30 40 50 60 70 80
# Preorder traversal:
# 50 30 20 40 70 60 80
# Postorder traversal:
# 20 40 30 60 80 70 50

# %%
# Pencarian nilai dalam BST

def search(node, key):
  if node is None or node.data == key:
    return node
  if key < node.data:
    return search(node.left, key)
  return search(node.right, key)

# Uji Pencarian
key = 60
result = search(root, key)
if result:
  print(f"{key} ditemukan dalam tree.")
else:
  print(f"{key} tidak ditemukan.")

key = 25
result = search(root, key)
if result:
  print(f"{key} ditemukan dalam tree.")
else:
  print(f"{key} tidak ditemukan.")
# Out:
# 60 ditemukan dalam tree.
# 25 tidak ditemukan.

# %%
# 1. Program Struktur Binary Tree Manual
# Struktur Tree berdasarkan identitas saya

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# Membuat tree secara manual
root = Node(21) # Jumlah huruf pada nama lengkap : Putri Senja Nuril Azizah
root.left = Node(9) # Jumlah huruf vokal = u, i, e, a, u, i, a, i, a
root.right = Node(36) # Dua digit akhir npm = 2505060036

# Tambahan node anak dari anak
root.left.left = Node(30) # Tanggal lahir
root.right.right = Node(11) # Bulan Lahir

#Fungsi inorder traversal
def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=' ')
        inorder(node.right)

print("Hasil inorder traversal identitas :")
inorder(root)
# Out:
# Hasil inorder traversal identitas :
# 30 9 21 36 11

# %%
# 2. Program Binary Search Tree

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class BinarySearchTree:
    def __init__(self):
        self.root = None

    def insert(self, root, data):
        if root is None:
            return Node(data)

        if data < root.data:
            root.left = self.insert(root.left, data)
        else:
            root.right = self.insert(root.right, data)

        return root

bst = BinarySearchTree()
root = None

# Data berdasarkan identitas
data_list = [36, 30, 11, 80, 117, 25, 77]
# NPM (036), DD(30), MM (11), ASCII P (80), ASCII u (117), angka favorit (25, 77)

for value in data_list:
    root = bst.insert(root, value)

# Traversal inorder
def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=' ')
        inorder(node.right)

# Traversal preorder
def preorder(node):
    if node:
        print(node.data, end=' ')
        preorder(node.left)
        preorder(node.right)

# Traversal postorder
def postorder(node):
    if node:
        postorder(node.left)
        postorder(node.right)
        print(node.data, end=' ')

print("Hasil Traversal dari BST identitas:")
print("**********************************")

print("Inorder Traversal:")
inorder(root)

print("\nPreorder Traversal:")
preorder(root)

print("\nPostorder Traversal:")
postorder(root)

# Fungsi pencarian
def search(node, key):
    if node is None or node.data == key:
        return node

    if key < node.data:
        return search(node.left, key)

    return search(node.right, key)

# Uji pencarian
print("\n\nUji Pencarian Nilai dalam BST")
print("*****************************")

key = 36
result = search(root, key)

if result:
    print(f"{key} ditemukan dalam tree.")
else:
    print(f"{key} tidak ditemukan.")

key = 7
result = search(root, key)

if result:
    print(f"{key} ditemukan dalam tree.")
else:
    print(f"{key} tidak ditemukan.")
# Out:
# Hasil Traversal dari BST identitas:
# **********************************
# Inorder Traversal:
# 11 25 30 36 77 80 117
# Preorder Traversal:
# 36 30 11 25 80 77 117
# Postorder Traversal:
# 25 11 30 77 117 80 36
#
# Uji Pencarian Nilai dalam BST
# *****************************
# 36 ditemukan dalam tree.
# 7 tidak ditemukan.
